# %%
! [ -e /content ] && pip install -Uqq fastbook
import fastbook
fastbook.setup_book()
# Out:
#      |████████████████████████████████| 719 kB 5.1 MB/s
#      |████████████████████████████████| 365 kB 61.0 MB/s
#      |████████████████████████████████| 1.3 MB 38.8 MB/s
#      |████████████████████████████████| 4.7 MB 22.7 MB/s
#      |████████████████████████████████| 115 kB 45.3 MB/s
#      |████████████████████████████████| 120 kB 44.7 MB/s
#      |████████████████████████████████| 212 kB 46.4 MB/s
#      |████████████████████████████████| 127 kB 42.7 MB/s
#      |████████████████████████████████| 6.6 MB 32.0 MB/s
# Mounted at /content/gdrive

# %%
# !pip install pickle5
# !pip install pmlb
# !pip install tqdm
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pickle5 in /usr/local/lib/python3.7/dist-packages (0.0.12)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pmlb in /usr/local/lib/python3.7/dist-packages (1.0.1.post3)
# Requirement already satisfied: pandas>=1.0.5 in /usr/local/lib/python3.7/dist-packages (from pmlb) (1.3.5)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.7/dist-packages (from pmlb) (6.0)
# Requirement already satisfied: requests>=2.24.0 in /usr/local/lib/python3.7/dist-packages (from pmlb) (2.28.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.0.5->pmlb) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.0.5->pmlb) (2022.2.1)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.0.5->pmlb) (1.21.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=1.0.5->pmlb) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.24.0->pmlb) (2022.6.15)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.24.0->pmlb) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.24.0->pmlb) (1.25.11)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.24.0->pmlb) (2.10)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (4.64.0)

# %%
from fastbook import *
from fastai.collab import *
from fastai.tabular.all import *
from numpy.linalg import norm
import pickle5 as pickle
import seaborn as sns
from pmlb import fetch_data
from sklearn.cross_decomposition import CCA
from tqdm import tqdm
from sklearn.manifold import TSNE
from sklearn.linear_model import LinearRegression
from sklearn.datasets import load_diabetes
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeRegressor

# %% [markdown]
# ## Load data and construct DataLoader

# %%
# load dataframe
filename = os.getcwd() + '/gdrive/MyDrive/data/multiple_datasets/data_ppl_acc_finalDF.csv'
data_df = pd.read_csv(filename)

# %%
test_frac = 0.1
test_df = data_df.sample(frac = test_frac)
train_df = data_df.drop(test_df.index)
train_df.shape, test_df.shape
# Out:
# ((6730, 3), (748, 3))

# %%
dls = CollabDataLoaders.from_df(train_df, seed=42, valid_pct=0.2, user_name='dataset_name', item_name='pipeline_name', rating_name='accuracy', bs=64)
dls.show_batch()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>dataset_name</th>
#       <th>pipeline_name</th>
#       <th>accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>64_hepatitis</td>
#       <td>['minmaxscaler', 'baggingclassifier']</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>63_heart_statlog</td>
#       <td>['rbfsampler', 'logisticregression']</td>
#       <td>0.555556</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>39_clean1</td>
#       <td>['perceptron']</td>
#       <td>0.916667</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>68_hypothyroid</td>
#       <td>['ridgeclassifier']</td>
#       <td>0.949447</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>120_wine_recognition</td>
#       <td>['sparsepca', 'randomforestclassifier']</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>94_postoperative_patient_data</td>
#       <td>['standardscaler', 'mlpclassifier']</td>
#       <td>0.777778</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>17_analcatdata_cyyoung9302</td>
#       <td>['logisticregression']</td>
#       <td>0.947368</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>93_pima</td>
#       <td>['decisiontreeclassifier']</td>
#       <td>0.759740</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>91_penguins</td>
#       <td>['isomap', 'extratreesclassifier']</td>
#       <td>0.686567</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>111_tic_tac_toe</td>
#       <td>['gradientboostingclassifier']</td>
#       <td>0.390625</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Initialize variables

# %%
n_users  = len(dls.classes['dataset_name'])
n_items = len(dls.classes['pipeline_name'])
n_factors = 40

dataset_names = [name[name.find("_")+1:] for name in dls.classes['dataset_name']]

# %% [markdown]
# ## Model

# %%
def create_params(size):
    return nn.Parameter(torch.zeros(*size).normal_(0, 0.01))


class DotProductBias(Module):
    def __init__(self, n_users, n_items, n_factors, y_range=(0,5.5)):
        self.user_factors = create_params([n_users, n_factors])
        self.user_bias = create_params([n_users])
        self.item_factors = create_params([n_items, n_factors])
        self.item_bias = create_params([n_items])
        self.y_range = y_range
        
    def forward(self, x):
        users = self.user_factors[x[:,0]]
        items = self.item_factors[x[:,1]]
        res = (users*items).sum(dim=1)
        res += self.user_bias[x[:,0]] + self.item_bias[x[:,1]]
        return sigmoid_range(res, *self.y_range)

# %% [markdown]
# ## Similarity Term: CCA score

# %%
def nchoose2_comb(n):
  """
  Return a <itertools.combinations> of all nChoose2 index combinations
  """
  idxs = list(range(n))
  comb = itertools.combinations(idxs, 2)
  return list(comb)

# %%
def get_CCA_score(d1_idx, d2_idx):
  d1_name, d2_name = dataset_names[d1_idx], dataset_names[d2_idx]
  X1, y1 = fetch_data(d1_name, return_X_y=True)
  X2, y2 = fetch_data(d2_name, return_X_y=True)
  min_num = min(X1.shape[0], X2.shape[0])
  min_dim = min(X1.shape[1], X2.shape[1])

  if X1.shape[0] > min_num:
    X1 = np.array(random.choices(X1, k=min_num))
  if X2.shape[0] > min_num:
    X2 = np.array(random.choices(X2, k=min_num))

  cca = CCA(n_components=min_dim)
  try:
    cca.fit(X1, X2)
  except ValueError:  # nan or inf in the matrix 
    return 0
  else: 
    return cca.score(X1, X2)

def get_CCAscore_matrix(comb):
  res_matrix = np.zeros((n_users, n_users))
  for r, (i, j) in tqdm(enumerate(comb)):
    # datasetID begin from 1!
    if i != 0 and j != 0:
      res_matrix[i, j] = get_CCA_score(i, j)
      res_matrix[j, i] = get_CCA_score(j, i)
  return res_matrix

# %%
# test get_CCA_score(i, j) == get_CCA_score(j, i)
get_CCA_score(1, 2), get_CCA_score(2, 1)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# (0.2975690647193751, 0.036041597805684646)

# %%
all_comb = nchoose2_comb(n_users)
sim_matrix = get_CCAscore_matrix(all_comb)
# Out:
# 0it [00:00, ?it/s]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 124it [01:51,  1.40s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 126it [02:27,  2.37s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 127it [03:14,  4.30s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 128it [07:17, 18.09s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 129it [07:26, 17.46s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 130it [11:47, 41.38s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 131it [11:50, 36.68s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 134it [14:11, 36.91s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 135it [15:39, 48.43s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 136it [15:52, 39.70s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 137it [16:23, 37.55s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 138it [17:46, 49.83s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 139it [20:25, 80.03s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 142it [22:22, 54.50s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 143it [24:16, 72.18s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 144it [24:21, 52.15s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 145it [26:14, 70.33s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 155it [29:50, 17.47s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 156it [31:12, 36.66s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 162it [32:06, 12.00s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 163it [32:12, 10.30s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 164it [33:34, 31.63s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 168it [34:41, 18.12s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 171it [35:28, 15.26s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 172it [37:53, 54.42s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 173it [39:12, 61.73s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 174it [41:36, 86.37s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 175it [42:55, 84.07s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 176it [56:39, 306.28s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 177it [56:46, 216.46s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 180it [57:29, 85.61s/it] /usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 181it [1:03:41, 171.54s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 182it [1:03:53, 123.81s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 185it [1:07:24, 75.77s/it] /usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 186it [1:08:41, 76.41s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 187it [1:09:02, 59.56s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 189it [1:10:04, 43.95s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 191it [1:10:35, 29.22s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 192it [1:12:28, 54.42s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 39
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 193it [1:12:37, 40.74s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 194it [1:13:23, 42.22s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 196it [1:13:32, 22.86s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 198it [1:14:54, 28.71s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 199it [1:15:01, 22.05s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 200it [1:15:07, 17.40s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 202it [1:15:18, 11.30s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 203it [1:15:31, 11.71s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 204it [1:15:43, 11.63s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 205it [1:15:49,  9.97s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 206it [1:17:25, 35.84s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 207it [1:17:42, 30.36s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 209it [1:22:53, 80.65s/it] /usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 212it [1:25:40, 53.95s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 213it [1:27:16, 66.62s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 215it [1:32:12, 96.77s/it] /usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 218it [1:53:39, 225.35s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 221it [1:58:35, 122.31s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 222it [1:58:41, 87.66s/it] /usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 223it [1:59:25, 74.50s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 225it [2:00:51, 54.68s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 226it [2:01:20, 47.05s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 228it [2:06:27, 90.87s/it] /usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 235it [2:09:22, 21.98s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 238it [2:09:40, 12.04s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 239it [2:09:47, 10.59s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 240it [2:12:11, 50.46s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 334it [2:16:15,  1.76s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 394it [2:18:00,  1.69s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 18
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 395it [2:18:02,  1.67s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 18
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 429it [2:19:06,  1.78s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 18
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 438it [2:19:21,  1.59s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 18
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 454it [2:19:55,  2.92s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 18
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 681it [2:27:36,  1.45s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 11
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 728it [2:28:52,  1.78s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 11
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 733it [2:29:01,  1.71s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 9
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 742it [2:29:15,  1.61s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 10
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 753it [2:29:32,  1.57s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 11
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 777it [2:30:17,  1.69s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 11
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 784it [2:30:29,  1.62s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 11
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 786it [2:30:32,  1.57s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 10
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 796it [2:30:49,  1.71s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 9
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 802it [2:31:01,  2.13s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 10
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 841it [2:32:10,  1.70s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 28
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 843it [2:32:14,  1.69s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 28
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 844it [2:32:15,  1.73s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 28
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 863it [2:32:45,  1.55s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 874it [2:33:07,  2.27s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 905it [2:34:03,  1.60s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 33
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 910it [2:34:14,  1.89s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 914it [2:34:21,  1.96s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 916it [2:34:30,  2.86s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 922it [2:34:42,  2.14s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 21
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 976it [2:36:56,  2.20s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 987it [2:37:29,  3.79s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 1004it [2:39:03,  3.07s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 39
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 1018it [2:39:33,  2.65s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 33
#   warnings.warn(f"Y residual is constant at iteration {k}")
# /usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 1027it [2:40:07,  3.85s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 1029it [2:40:33,  7.51s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 55
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 1038it [2:41:01,  2.96s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 1079it [2:42:47,  1.61s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 20
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 1139it [2:44:25,  1.62s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 1147it [2:44:48,  2.47s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 21
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 1150it [2:44:52,  1.76s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 1169it [2:45:25,  2.14s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 1199it [2:46:33,  1.84s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 1208it [2:46:55,  3.03s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 1227it [2:48:18,  2.83s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 39
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 1241it [2:48:48,  2.47s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 33
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 1250it [2:49:29,  5.81s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 1252it [2:50:02, 10.10s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 1393it [2:54:16,  2.39s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 28
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 1411it [2:54:49,  1.75s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 23
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 1412it [2:54:51,  1.71s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 23
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 1418it [2:55:00,  1.61s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 26
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 1422it [2:55:06,  1.56s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 25
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 1446it [2:56:09,  2.15s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 24
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 1460it [2:56:35,  2.04s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 27
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 1471it [2:57:11,  4.11s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 22
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 1750it [3:06:01,  2.83s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 1757it [3:06:22,  2.58s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 1767it [3:06:42,  1.94s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 40
#   warnings.warn(f"Y residual is constant at iteration {k}")
# /usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 41
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 1786it [3:07:18,  2.12s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 1790it [3:07:27,  2.29s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 1792it [3:07:39,  3.76s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 42
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 1797it [3:07:51,  2.41s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 42
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 2181it [3:21:08,  2.58s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 39
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 2195it [3:21:35,  2.19s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 33
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 2206it [3:22:18,  5.14s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 2215it [3:22:40,  2.45s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 2234it [3:23:28,  1.96s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 26
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 2254it [3:24:24,  2.47s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 2270it [3:24:55,  1.82s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 2272it [3:25:00,  1.97s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 2295it [3:26:28,  2.81s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 24
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 2544it [3:34:24,  2.21s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 22
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 2545it [3:34:26,  2.03s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 26
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 2555it [3:34:42,  1.71s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 27
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 2560it [3:34:53,  2.28s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 27
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 2576it [3:35:42,  1.99s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 25
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 2579it [3:35:49,  2.52s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 25
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 2593it [3:36:13,  1.86s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 25
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 2602it [3:36:34,  2.24s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 2604it [3:36:47,  3.84s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 23
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 2609it [3:36:56,  2.06s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 27
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 2683it [3:39:02,  1.80s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 12
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 2699it [3:39:29,  1.75s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 2737it [3:40:36,  2.00s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 24
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 2738it [3:40:38,  1.92s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 25
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 2748it [3:40:55,  1.76s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 28
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 2753it [3:41:06,  2.34s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 27
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 2769it [3:41:52,  1.84s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 25
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 2772it [3:41:58,  2.06s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 25
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 2797it [3:42:55,  3.93s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 23
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 2802it [3:43:05,  2.06s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 26
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 2833it [3:44:27,  1.80s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 23
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 2843it [3:44:44,  1.63s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 26
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 2864it [3:45:58,  2.25s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 27
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 2867it [3:46:05,  2.24s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 25
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 2881it [3:46:30,  1.97s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 28
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 2892it [3:47:05,  3.85s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 25
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 3076it [3:52:26,  1.72s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 5
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 3127it [3:53:49,  1.57s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 3168it [3:54:51,  1.58s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 5
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 3259it [3:57:04,  1.47s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 5
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 3480it [4:02:40,  1.50s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 3519it [4:03:56,  1.61s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 3613it [4:06:34,  1.73s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 5
# ...
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 6207it [5:41:52,  1.89s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 6217it [5:42:07,  1.61s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 21
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 6218it [5:42:09,  1.63s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 33
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 6219it [5:42:11,  1.67s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 39
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 6221it [5:42:15,  1.86s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 34
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 6225it [5:42:22,  1.72s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 39
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 6227it [5:42:26,  1.76s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 39
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 6229it [5:42:33,  2.58s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 38
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 6230it [5:42:35,  2.49s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 40
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 6234it [5:42:42,  1.82s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 39
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 6235it [5:42:45,  2.02s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 21
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 6238it [5:42:50,  1.74s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 39
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 6252it [5:43:13,  1.67s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 21
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 6320it [5:45:11,  1.48s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 6364it [5:46:12,  1.43s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 5
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 6395it [5:47:22,  1.48s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 6651it [5:54:47,  1.71s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 5
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 6655it [5:54:55,  1.86s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 6677it [5:55:23,  1.28s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 21
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 6721it [5:56:31,  1.54s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 12
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 6727it [5:56:42,  1.75s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 12
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 6751it [5:57:18,  1.53s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 24
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 6760it [5:57:39,  2.29s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 6762it [5:57:50,  3.72s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 21
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 6767it [5:57:59,  2.02s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 24
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 6786it [5:58:35,  2.02s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 33
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 6788it [5:58:40,  2.14s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 33
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 6792it [5:58:46,  1.77s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 33
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 6794it [5:58:50,  1.82s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 6796it [5:58:57,  2.51s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 33
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 6797it [5:59:00,  2.53s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 33
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 6801it [5:59:07,  1.78s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 33
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 6818it [5:59:31,  1.27s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 33
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 6827it [5:59:56,  3.24s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 6834it [6:00:51,  4.23s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 6890it [6:02:51,  2.27s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 6892it [6:03:06,  4.38s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 34
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 6948it [6:04:49,  1.74s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 5
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 6988it [6:06:00,  1.83s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 7004it [6:06:28,  1.72s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 7006it [6:07:08,  9.53s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 7007it [6:07:11,  7.60s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 7032it [6:08:24,  2.63s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 5
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 7034it [6:08:29,  2.52s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 5
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 7046it [6:08:47,  1.42s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 5
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 7049it [6:08:50,  1.25s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 5
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 7058it [6:09:06,  2.27s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 7062it [6:09:41,  4.94s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 7064it [6:10:05,  8.16s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 7066it [6:10:10,  5.54s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 7110it [6:12:27,  2.15s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 21
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 7113it [6:12:32,  1.75s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 56
#   warnings.warn(f"Y residual is constant at iteration {k}")
# /usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 7127it [6:12:55,  1.72s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 21
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 7131it [6:13:03,  1.85s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 7135it [6:13:18,  2.77s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 7213it [6:15:18,  1.57s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 57
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 7227it [6:15:46,  1.97s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 21
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 7287it [6:17:31,  1.77s/it]/usr/local/lib/python3.7/dist-packages/sklearn/cross_decomposition/_pls.py:107: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# 7381it [6:20:01,  3.09s/it]

# %%
# store the ACCscore_vector into pickle file
# path = os.getcwd() + '/gdrive/MyDrive/data/multiple_datasets/'
# with open(path + 'full_sim_matrix.pickle', 'wb') as f:
#     pickle.dump(sim_matrix, f)

# %%
# readout data
path = os.getcwd() + '/gdrive/MyDrive/data/multiple_datasets/'
with open(path + 'full_sim_matrix.pickle', 'rb') as f:
    sim_matrix = pickle.load(f)

# %%
sim_matrix, sim_matrix.shape
# Out:
# (array([[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 0.00000000e+00,  0.00000000e+00,  4.02397251e-01, ...,  6.12687634e-01, -3.44919648e+00,  6.07122540e-01],
#         [ 0.00000000e+00,  3.49627904e-02,  0.00000000e+00, ..., -5.31724791e-01, -6.86463033e+00, -7.54767172e-01],
#         ...,
#         [ 0.00000000e+00,  1.86534811e-02, -4.41482615e-01, ...,  0.00000000e+00, -4.43075961e+00, -6.56943247e-01],
#         [ 0.00000000e+00,  1.43484778e-02,  8.03574874e-02, ...,  6.44446905e-02,  0.00000000e+00,  1.33213171e-02],
#         [ 0.00000000e+00,  3.13738156e-03, -2.60099256e-01, ..., -2.10705541e-01, -1.32388138e+01,  0.00000000e+00]]),
#  (122, 122))

# %%
# lower-cut at threshold=-100, sigmoid to range=(0, 1)
def cut_sigmoid(matrix, threshold=-100, low=0, high=1):
  # first clip the matrix by low bound=threshold
  matrix[matrix < threshold] = threshold
  # ignore first row & col, datasetID begin from index 1
  curr = torch.tensor(matrix[1:, 1:])
  # then, do the sigmoid on the matrix to the range [low, high]
  sigmoid_matrix = torch.sigmoid(curr) * (high - low) + low
  # add first row & col back
  res_matrix = np.zeros((n_users, n_users))
  res_matrix[1:, 1:] = sigmoid_matrix.numpy()
  return res_matrix


sim_matrix = cut_sigmoid(sim_matrix, threshold=-100, low=0, high=1)
sim_matrix, sim_matrix.shape
# Out:
# (array([[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ..., 0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 5.00000000e-01, 5.99263489e-01, ..., 6.48553644e-01, 3.07928312e-02, 6.47284135e-01],
#         [0.00000000e+00, 5.08739807e-01, 5.00000000e-01, ..., 3.70114698e-01, 1.04297940e-03, 3.19783446e-01],
#         ...,
#         [0.00000000e+00, 5.04663235e-01, 3.91387748e-01, ..., 5.00000000e-01, 1.17653708e-02, 3.41426603e-01],
#         [0.00000000e+00, 5.03587058e-01, 5.20078569e-01, ..., 5.16105599e-01, 5.00000000e-01, 5.03330280e-01],
#         [0.00000000e+00, 5.00784345e-01, 4.35339309e-01, ..., 4.47517642e-01, 1.78014521e-06, 5.00000000e-01]]),
#  (122, 122))

# %% [markdown]
# ## My Learner

# %%
class MyLearner(Learner):
    @delegates(Learner.__init__)
    def __init__(self,
                 dls,  # `DataLoaders` containing data for each dataset needed for `model`
                 model:callable, #  The model to train or use for inference
                 loss_func:Union[callable, None]=None,  # Loss function for training
                 opt_func=Adam,  # Optimisation function for training
                 lr=defaults.lr,  # Learning rate
                 splitter:callable=trainable_params,  # Used to split parameters into layer groups
                 cbs=None,  # Callbacks
                 metrics=None,  # Printed after each epoch
                 path=None,  # Parent directory to save, load, and export models
                 model_dir='models',  # Subdirectory to save and load models
                 wd=None,  # Weight decay
                 wd_bn_bias=False,  # Apply weight decay to batchnorm bias params?
                 train_bn=True,  # Always train batchnorm layers?
                 moms=(0.95,0.85,0.95),  # Momentum
                 default_cbs:bool=True,  # Include default callbacks?
                 sim_lambda=0.,
                 l1_lambda=0.,
                 l2_lambda=0.,
                 decouple_wd=True,
                 **kwargs
                ):
        super().__init__(dls=dls, model=model, loss_func=loss_func, opt_func=opt_func, lr=lr,
                         splitter=splitter, cbs=cbs, metrics=metrics, path=path, model_dir=model_dir, 
                         wd=wd, wd_bn_bias=wd_bn_bias, train_bn=train_bn, moms=moms, default_cbs=default_cbs, **kwargs)
        self.sim_lambda, self.l1_lambda, self.l2_lambda = sim_lambda, l1_lambda, l2_lambda
        self.decouple_wd = decouple_wd

    ############################ add regularization ############################
    def l1_reg(self):
        user_factors_w1 = self.model.user_factors.abs().sum()
        user_bias_w1 = self.model.user_bias.abs().sum()
        item_factors_w1 = self.model.item_factors.abs().sum()
        item_bias_w1 = self.model.item_bias.abs().sum()
        l1_norm = user_factors_w1 + user_bias_w1 + item_factors_w1 + item_bias_w1
        return self.l1_lambda * l1_norm

    def l2_reg(self):
        user_factors_w2 = self.model.user_factors.pow(2).sum()
        user_bias_w2 = self.model.user_bias.pow(2).sum()
        item_factors_w2 = self.model.item_factors.pow(2).sum()
        item_bias_w2 = self.model.item_bias.pow(2).sum()
        l2_norm = user_factors_w2 + user_bias_w2 + item_factors_w2 + item_bias_w2
        return self.l2_lambda * l2_norm
    
    def sim_term(self, batch_comb):
        batch_scores1 = torch.tensor([sim_matrix[int(d1), int(d2)] for (d1, d2) in batch_comb], dtype=torch.float32)
        batch_scores2 = torch.tensor([sim_matrix[int(d2), int(d1)] for (d1, d2) in batch_comb], dtype=torch.float32)
        return self.sim_lambda * (batch_scores1.sum() + batch_scores2.sum())
    ############################################################################
    
    def _do_one_batch(self):
        self.pred = self.model(*self.xb)
        self('after_pred')
        if len(self.yb):
            self.loss_grad = self.loss_func(self.pred, *self.yb)
            # self.loss = self.loss_grad.clone()
            # add regularization to loss, limit sim_term to batches
            dataset_idxs = self.xb[0][:, 0] # NOTE: ID begins from 1
            batch_comb = list(itertools.combinations(dataset_idxs, 2))
            self.loss = self.loss_grad.clone() + self.sim_term(batch_comb) + self.l1_reg() + self.l2_reg()
        self('after_loss')
        if not self.training or not len(self.yb): return
        self._with_events(self._backward, 'backward', CancelBackwardException)
        self._with_events(self._step, 'step', CancelStepException)
        self.opt.zero_grad()

# %% [markdown]
# ## My model train

# %%
my_model = DotProductBias(n_users, n_items, n_factors, y_range=(0, 1.5))
learn_wd = MyLearner(dls, my_model, loss_func=MSELossFlat(), opt_func=Adam, lr=1e-3, cbs=[ShowGraphCallback()], wd=1e-3, sim_lambda=1e-2, l1_lambda=0., l2_lambda=0., decouple_wd=True) # wd, Adam
# learn_sgd = MyLearner(dls, my_model, loss_func=MSELossFlat(), opt_func=SGD, lr=1e-10, cbs=[ShowGraphCallback()], wd=0., sim_lambda=1e-2, l1_lambda=5e-3, l2_lambda=5e-3, decouple_wd=False) # SGD
learn_wd.fit(10)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>15.333955</td>
#       <td>15.357496</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>15.357194</td>
#       <td>15.353451</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>15.315275</td>
#       <td>15.348535</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>15.359025</td>
#       <td>15.344388</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>15.294396</td>
#       <td>15.341808</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>15.332424</td>
#       <td>15.340236</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>15.341068</td>
#       <td>15.339218</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>15.299057</td>
#       <td>15.338449</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>15.306553</td>
#       <td>15.337913</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>15.297821</td>
#       <td>15.337425</td>
#       <td>00:01</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## My model test

# %%
test_dls = dls.test_dl(test_df)
preds, labels = learn_wd.get_preds(dl=test_dls)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
rows = []
for idx, (user, item, actual_y, pred_y) in enumerate(sorted(zip(test_df.dataset_name, test_df.pipeline_name, test_df.accuracy, preds), reverse=True)):
  actual, pred = test_df.accuracy.iloc[idx], float(preds[idx])
  rows.append(dict({'user': test_df.dataset_name.iloc[idx], 'item': test_df.pipeline_name.iloc[idx], 'actual_acc': actual, 'pred_acc': pred}))
test_result = pd.DataFrame(rows)
test_result.head()
# Out:
#                 user  \
# 0            85_mux6
# 1  103_solar_flare_1
# 2     78_mofn_3_7_10
# 3     78_mofn_3_7_10
# 4       67_hungarian
#
#                                                           item  actual_acc  \
# 0                                    ['truncatedsvd', 'nusvc']    0.500000
# 1      ['logisticregressionfeature', 'randomforestclassifier']    0.682540
# 2                                  ['standardscaler', 'nusvc']    1.000000
# 3                                ['powertransformer', 'nusvc']    1.000000
# 4  ['gradientboostingclassifierfeature', 'adaboostclassifier']    0.847458
#
#    pred_acc
# 0  0.664101
# 1  0.760685
# 2  0.971670
# 3  0.985243
# 4  0.775724

# %%
# act, pre = np.array(test_result.actual_acc), np.array(test_result.pred_acc)
error_rates = np.absolute(np.divide(preds-labels, labels))
mean_acc = 1 - error_rates.mean()
float(mean_acc)
# Out:
# 0.705483078956604

# %% [markdown]
# # Result Analysis: Factors Histogram
# Plot the Histogram of **user_factors** (dataset_factors) and **item_factors** (pipeline_factors)

# %%
# (wd) dataset_factors Histogram
x = learn_wd.model.user_factors.detach().numpy()
num_bins = 10
# the histogram of the data
n, bins, patches = plt.hist(x, num_bins, facecolor='blue', alpha=0.5)

plt.xlabel('dataset factors')
plt.ylabel('counts')
plt.title('Histogram of wd dataset factors (#bins=10)')
plt.show()

# %%
# (wd) pipeline_factors Histogram
x = learn_wd.model.item_factors.detach().numpy()
num_bins = 20
# the histogram of the data
n, bins, patches = plt.hist(x, num_bins, facecolor='blue', alpha=0.5)

# add a 'best fit' line
plt.xlabel('pipeline factors')
plt.ylabel('counts')
plt.title('Histogram of wd pipeline factors (#bins=20)')
plt.show()

# %% [markdown]
# # Result Analysis: Data Clustering

# %%
def text_clean(name, newline=False):
  substitutes = {"classifier": "Clas", "feature": "Feat", "gaussian": "Gaus", 
                "perceptron": "Percpt", "quadratic": "Quad", "polynomial": "Poly", 
                "ing": "", "multinomial": "Mltnom", "transformer": "Transf", 
                "transformation": "Transft", "threshold": "Thres", "neighbors": "Neigbs",
                 "gradient": "Grad", "standard": "Stad", "percentile": "Percent", 
                 "passive": "Pass", "aggressive": "Aggre", "elimination": "Elim", 
                 "discriminant": "Discrim", "analysis": "Analy", "random": "Rand", 
                 "variance": "Var", "decision": "Dec", "agglomeration": "Aggl", 
                 "trees": "Tre", "extra": "Extr", "additive": "Addi", "bernoullinb": "Bernlinb", 
                 "sampler": "Sampl"}
  for key, val in substitutes.items():
    name = name.replace(key, val)
  if not newline:
    return name
  
  # split add newline
  dataset_name = name.split(",")
  curr_i = ""
  if len(dataset_name) > 1:
    for name in dataset_name:
      curr_i += (name + '\n')
    curr_i = curr_i[:-1]
  else:
    curr_i = name
  return curr_i

# %%
# focus on specific (target) pipelines
g = data_df.groupby('pipeline_name')['accuracy'].count()
top_pipelines = list(g.sort_values(ascending=False).index.values[:830])
target_pipelines = ["['skewedchi2sampler', 'extratreesclassifierfeature', 'baggingclassifier']", 
                    "['skewedchi2sampler', 'mlpclassifierfeature', 'baggingclassifier']", 
                    "['normalizer', 'quantilescalinguniform', 'skewedchi2sampler', 'extratreesclassifier']", 
                    "['powertransformer', 'quantilescalinguniform', 'skewedchi2sampler', 'extratreesclassifier']"]
target_idx = []
for ppl in target_pipelines:
  target_idx.append(top_pipelines.index(ppl))
target_idx
# Out:
# [802, 776, 733, 751]

# %%
g = data_df.groupby('pipeline_name')['accuracy'].count()
acc_g = data_df.groupby('pipeline_name').mean() 
acc_dict = acc_g.to_dict('dict')['accuracy']

top_pipelines = g.sort_values(ascending=False).index.values[:830]
top_idxs = tensor([learn_wd.dls.classes['pipeline_name'].o2i[m] for m in top_pipelines])
pipeline_w = learn_wd.model.item_factors[top_idxs].cpu().detach() # pipeline_factors
pipeline_pca = pipeline_w.pca(3)
fac0,fac1,fac2 = pipeline_pca.t()
idxs = list(range(100)) # 50
# add pipeline idxs with 3 steps and 4 steps
idxs += target_idx

X = fac0[idxs]
Y = fac1[idxs] # Y = fac2[idxs]
fig = plt.figure(figsize=(30,30))
plt.scatter(X, Y)

cluster_point = 0
for i, x, y in zip(top_pipelines[idxs], X, Y):
  plt.text(x,y, str(round(acc_dict[i], 2)) + "\n" + text_clean(i, newline=True), color=np.random.rand(3)*0.7, fontsize=10)
  cluster_point += 1

fig.suptitle('Representation of pipelines based on two strongest PCA components' + '\n' + 'Number of cluster point: ' + str(cluster_point), fontsize=20)
plt.show()

# %% [markdown]
# # Result Analysis: Data Clustering (x, y) = (pipeline_bias, avg_accuracy)

# %%
g = data_df.groupby('pipeline_name')['accuracy'].count()
acc_g = data_df.groupby('pipeline_name').mean() 
acc_dict = acc_g.to_dict('dict')['accuracy']

all_pipelines = g.sort_values(ascending=False).index.values[:830] # include a distinct pipelines
all_idxs = tensor([learn_wd.dls.classes['pipeline_name'].o2i[m] for m in all_pipelines]) # occurance (keep)
pipeline_b = learn_wd.model.item_bias[all_idxs].cpu().detach()  # pipeline_bias

acc_tensor = []
for ppl in all_pipelines:
  acc_tensor.append(acc_dict[ppl])
acc_tensor =  torch.Tensor(acc_tensor)

idxs = list(range(100)) # 830: choose all pipeline (n: topN occurrence)
# add pipeline idxs with 3 steps and 4 steps
idxs += target_idx

X = pipeline_b[idxs]
Y = acc_tensor[idxs]

fig = plt.figure(figsize=(30,30))
plt.scatter(X, Y)
# add labels
fig.suptitle('Pipeline points clustering \n (x, y) = (pipeline_bias, avg_accuracy)', fontsize=50)
plt.xlabel('Pipeline Bias', fontsize=30)
plt.ylabel('Average Accuracy', fontsize=30)

cluster_point = 0
for i, x, y in zip(all_pipelines[idxs], X, Y):
  plt.text(x,y, text_clean(i, newline=True), color=np.random.rand(3)*0.7, fontsize=11)
  cluster_point += 1

plt.show()
print('Number of cluster point: ', cluster_point)
# Out:
# Number of cluster point:  104

# %% [markdown]
# # Result Analysis: TSNE Data Clustering (x, y) = (TSNE_factor[0], TSNE_factor[1])

# %%
# get the avg acc of each dataset
def get_avg_accs(data_df):
  dataset_avg_acc = {}
  for name in dls.classes['dataset_name']:
    if name != '#na#':
      curr_df = data_df.loc[data_df['dataset_name'] == name]
      avg_acc = sum(curr_df['accuracy']) / curr_df.shape[0]
      dataset_avg_acc[name] = avg_acc
  return dataset_avg_acc

dataset_avg_acc = get_avg_accs(data_df)

# %%
# set hue
y = []
for name in dls.classes['dataset_name']:
  if name != '#na#':
    curr_acc = dataset_avg_acc[name]
    curr_hue = int(curr_acc * 10)
    y.append(curr_hue)

# %%
sns.set(rc={'figure.figsize':(20, 20)})
n_cluster = len(set(y))  # n_users-1
palette = sns.color_palette("bright",n_cluster)
  
tsne = TSNE(n_components=2, random_state=0)
factor_embedded = tsne.fit_transform(learn_wd.model.user_factors.detach().numpy())
sns.scatterplot(factor_embedded[1:, 0], factor_embedded[1:, 1], hue=y, legend='full', palette=palette)

# add annotation
for i, name in enumerate(dls.classes['dataset_name']):
  if name != '#na#':
    curr_acc = round(dataset_avg_acc[name], 2)
    x, y = factor_embedded[i]
    plt.text(x, y, curr_acc)

# Add title and axis names
plt.title('TSNE Data Clustering (x, y) = (TSNE_factor[0], TSNE_factor[1])', fontsize=20)
plt.xlabel('TSNE_factor[0]', fontsize=15)
plt.ylabel('TSNE_factor[1]', fontsize=15)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # Result Analysis: TSNE Data Clustering (x, y) = (TSNE_factor[0], avg_accuracy)

# %%
sns.set(rc={'figure.figsize':(20, 20)})
n_cluster = len(set(y))  # n_users-1
palette = sns.color_palette("bright",n_cluster)

fac_x = list(factor_embedded[1:, 0])
acc_y = []
for name in dls.classes['dataset_name']:
  if name != '#na#':
    acc_y.append(dataset_avg_acc[name])
sns.scatterplot(fac_x, acc_y, hue=y, legend='full', palette=palette)

# add annotation
for i in range(len(acc_y)):
    plt.text(fac_x[i], acc_y[i], round(acc_y[i], 2))

# Add title and axis names
plt.title('(x, y) = (TSNE_factor[0], avg_accuracy)', fontsize=20)
plt.xlabel('TSNE_factor[0]', fontsize=15)
plt.ylabel('avg_accuracy', fontsize=15)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # Result Analysis: Linear Regression with (Xs, Y) = (TSNE_factor[0] & TSNE_factor[1], avg_accuracy)

# %%
X = factor_embedded[1:, :]
y = np.array(acc_y)
reg = LinearRegression().fit(X, y)
reg.score(X, y) # score ~= 0.8

# %% [markdown]
# # Result Analysis: DecisionTreeRegressor with (Xs, Y) = (TSNE_factor[0] & TSNE_factor[1], avg_accuracy)

# %% [markdown]
# #### 1) DecisionTreeRegressor with max_depth=2 or max_depth=5

# %%
X = factor_embedded[1:, :]
y = np.array(acc_y)

# Fit regression model
regr_1 = DecisionTreeRegressor(max_depth=2)
regr_2 = DecisionTreeRegressor(max_depth=5)
regr_1.fit(X, y)
regr_2.fit(X, y)

regr_1.score(X, y), regr_2.score(X, y)

# %% [markdown]
# #### 2) Cross Validation

# %%
regressor = DecisionTreeRegressor(random_state=0, max_depth=5)
cross_scores = cross_val_score(regressor, X, y, cv=10)
cross_scores, cross_scores.mean()
